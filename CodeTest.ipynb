# %% [markdown]
# # We will only need one of the two to work!
# If the first approach failed, try the second one.
# Report any issue if both  method fail to download.

# %% [markdown]
# ### Code for normal access: this requires access from Meta

# %%
# !pip install --quiet huggingface_hub

# %%
from huggingface_hub import snapshot_download, notebook_login
 # copy your HuggingFace access token and paste it here
notebook_login()
# You should see "Login successful"

# %%
snapshot_download(repo_id="meta-llama/Meta-Llama-3-8B", local_dir='./Llama3-8b', ignore_patterns=['*.pth'])
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# USE_POLICY.md:   0%|          | 0.00/4.70k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/36.5k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/7.80k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# original/params.json:   0%|          | 0.00/211 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# ...

# %% [markdown]
# Error Case:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Success case: (waiting for download)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If your download is successful, click on the folder icon of the left panel, you should see these files.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Code for using alternative checkpoint
# You need to run this only if your normal access fails

# %%
snapshot_download(repo_id="nousresearch/Meta-Llama-3-8B", local_dir='./Llama3-8b_nousresearch', ignore_patterns=['*.pth'])
# Out:
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/36.6k [00:00<?, ?B/s]
# USE_POLICY.md:   0%|          | 0.00/4.70k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/7.80k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# ...

# %% [markdown]
# Make sure your download is successful.
# Success case: (waiting for download)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Check the result in folders:
#
# ![image.png](data:image/png;base64,...)
